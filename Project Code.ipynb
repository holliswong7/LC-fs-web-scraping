# %% [markdown]
# ## AF5365 - Applications of Computing and Technology in Accounting and Finance I
# ## Group Project - Source Code of Analysis

# %% [markdown]
# ##### LendingClub Corporation (LC  US:NYSE)
# LendingClub Corporation provides Internet financial services. The Company hosts an online financial community that brings together credit worthy borrowers and independent investors for their mutual benefits. LendingClub serves retail investors and borrowers in the United States.

# %% [markdown]
# ### Part 1: Web Scraping

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# url for recent 10-K
url = 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/0001409970-19-000222.txt'

# remove the 'ACCESSION NUMBER' to get the base url
base_url = url.replace('/0001409970-19-000222.txt','')

# %%
# all the related filing can be found in the base_url
base_url
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222'

# %%
# url for FilingSummary.xml
filing_summary_url = base_url + '/FilingSummary.xml'
filing_summary_url
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/FilingSummary.xml'

# %%
# 'FilingSummary.xml' contains information for the filing
summary_content = requests.get(filing_summary_url).content

soup = BeautifulSoup(summary_content, 'lxml')

reports = soup.find('myreports')

# create a list to store file information
all_reports = []

for report in reports.find_all('report')[:-1]:
    
    # create a dictionary contains information for 'short name' and 'url'
    report_dict = {}
    report_dict['short_name'] = report.shortname.text
    report_dict['url'] = base_url + '/' + report.htmlfilename.text
    
    all_reports.append(report_dict)

# %%
len(all_reports)
# Out:
# 103

# %%
all_reports
# Out:
# [{'short_name': 'Document and Entity Information',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R1.htm'},
#  {'short_name': 'Consolidated Balance Sheets',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R2.htm'},
#  {'short_name': 'Consolidated Balance Sheets (Parenthetical)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R3.htm'},
#  {'short_name': 'Consolidated Statements of Operations',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R4.htm'},
#  {'short_name': 'Consolidated Statements of Comprehensive Income (Loss)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R5.htm'},
#  {'short_name': "Consolidated Statements of Changes in Stockholders' Equity",
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R6.htm'},
#  {'short_name': 'Consolidated Statements of Cash Flows',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R7.htm'},
#  {'short_name': 'Consolidated Statements of Cash Flows Consolidated Statements of Cash Flows (Parenthetical)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R8.htm'},
#  {'short_name': 'Basis of Presentation',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R9.htm'},
#  {'short_name': 'Summary of Significant Accounting Policies',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R10.htm'},
#  {'short_name': 'Revenue from Contracts with Customers',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R11.htm'},
#  {'short_name': 'Net Loss Per Share',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R12.htm'},
#  {'short_name': 'Securities Available for Sale',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R13.htm'},
#  {'short_name': 'Loans Held for Investment, Loans Held for Sale, Notes, Certificates and Secured Borrowings',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R14.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R15.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R16.htm'},
#  {'short_name': 'Property, Equipment and Software, Net',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R17.htm'},
#  {'short_name': 'Other Assets',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R18.htm'},
#  {'short_name': 'Intangible Assets and Goodwill',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R19.htm'},
#  {'short_name': 'Accrued Expenses and Other Liabilities',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R20.htm'},
#  {'short_name': 'Accumulated Other Comprehensive Loss',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R21.htm'},
#  {'short_name': 'Debt',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R22.htm'},
#  {'short_name': 'Secured Borrowings',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R23.htm'},
#  {'short_name': "Stockholders' Equity",
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R24.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R25.htm'},
#  {'short_name': 'Income Taxes',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R26.htm'},
#  {'short_name': 'Commitments and Contingencies',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R27.htm'},
#  {'short_name': 'Segment Reporting',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R28.htm'},
#  {'short_name': 'Related Party Transactions',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R29.htm'},
#  {'short_name': 'Subsequent Events',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R30.htm'},
#  {'short_name': 'Quarterly Results of Operations (Unaudited)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R31.htm'},
#  {'short_name': 'Summary of Significant Accounting Policies (Policies)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R32.htm'},
#  {'short_name': 'Revenue from Contracts with Customers (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R33.htm'},
#  {'short_name': 'Net Loss Per Share (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R34.htm'},
#  {'short_name': 'Securities Available for Sale (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R35.htm'},
#  {'short_name': 'Loans Held for Investment, Loans Held for Sale, Notes, Certificates and Secured Borrowings (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R36.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R37.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R38.htm'},
#  {'short_name': 'Property, Equipment and Software, Net (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R39.htm'},
#  {'short_name': 'Other Assets (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R40.htm'},
#  {'short_name': 'Intangible Assets and Goodwill (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R41.htm'},
#  {'short_name': 'Accrued Expenses and Other Liabilities (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R42.htm'},
#  {'short_name': 'Accumulated Other Comprehensive Loss (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R43.htm'},
#  {'short_name': "Stockholders' Equity (Tables)",
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R44.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R45.htm'},
#  {'short_name': 'Income Taxes (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R46.htm'},
#  {'short_name': 'Commitments and Contingencies (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R47.htm'},
#  {'short_name': 'Quarterly Results of Operations (Unaudited) (Tables)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R48.htm'},
#  {'short_name': 'Summary of Significant Accounting Policies (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R49.htm'},
#  {'short_name': 'Revenue from Contracts with Customers (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R50.htm'},
#  {'short_name': 'Net Loss Per Share (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R51.htm'},
#  {'short_name': 'Securities Available for Sale - Amortized cost/fair value (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R52.htm'},
#  {'short_name': 'Securities Available for Sale - Unrealized losses (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R53.htm'},
#  {'short_name': 'Securities Available for Sale - Maturities (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R54.htm'},
#  {'short_name': 'Securities Available for Sale - Realized gains/losses (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R55.htm'},
#  {'short_name': 'Loans Held for Investment, Loans Held for Sale, Notes, Certificates and Secured Borrowings - Fair value on a recurring basis (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R56.htm'},
#  {'short_name': 'Loans Held for Investment, Loans Held for Sale, Notes, Certificates and Secured Borrowings - Additional Information (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R57.htm'},
#  {'short_name': 'Loans Held for Investment, Loans Held for Sale, Notes, Certificates and Secured Borrowings - Outstanding loans (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R58.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities - Summary of Select Information Related to VIEs (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R59.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities - Summary of Financial Asset and Liabilitiy Involvement with Consolidated VIEs (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R60.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities - Unconsolidated VIEs with Significant Continuing Involvement (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R61.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities - Summary of Personal Whole Loan Securitizations and Sales (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R62.htm'},
#  {'short_name': 'Securitizations and Variable Interest Entities - Off-balance Sheet Loans Sold or Securitized (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R63.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Loans, Loan Servicing Rights, Related Notes and Certificates (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R64.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Quantitative Information about Significant Unobservable Inputs Used for Fair Value Measurements (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R65.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Additional Information about Loans, Notes, Certificates and Secured Borrowings Measured at Fair Value on Recurring Basis (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R66.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Sensitivity of Fair Value of Loans Invested in by Company (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R67.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Additional Information about Servicing Assets and Liabilities Measured at Fair Value on Recurring Basis (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R68.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Additional Information about Servicing Assets and Liabilities Measured Using Different Market Servicing Rates and Different Prepayment (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R69.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Trailing Fee Liability (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R70.htm'},
#  {'short_name': 'Fair Value of Assets and Liabilities - Not Measured at Fair Value (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R71.htm'},
#  {'short_name': 'Property, Equipment and Software, Net (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R72.htm'},
#  {'short_name': 'Property, Equipment and Software, Net - Additional Information (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R73.htm'},
#  {'short_name': 'Other Assets (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R74.htm'},
#  {'short_name': 'Intangible Assets and Goodwill - Additional Information (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R75.htm'},
#  {'short_name': 'Intangible Assets and Goodwill - Schedule of Intangible Assets (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R76.htm'},
#  {'short_name': 'Intangible Assets and Goodwill - Schedule of Expected Future Amortization Expense for Intangible Assets (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R77.htm'},
#  {'short_name': 'Intangible Assets and Goodwill - Schedule of Goodwill (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R78.htm'},
#  {'short_name': 'Accrued Expenses and Other Liabilities (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R79.htm'},
#  {'short_name': 'Accumulated Other Comprehensive Loss - Comprehensive income/loss (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R80.htm'},
#  {'short_name': 'Accumulated Other Comprehensive Loss - Accumulated other comprehensive income/loss (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R81.htm'},
#  {'short_name': 'Debt (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R82.htm'},
#  {'short_name': 'Secured Borrowings (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R83.htm'},
#  {'short_name': "Stockholders' Equity - Additional Information (Detail)",
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R84.htm'},
#  {'short_name': "Stockholders' Equity - Shares of Common Stock Reserved for Future Issuance (Detail)",
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R85.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Total Stock-Based Compensation Expense (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R86.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Stock-Based Compensation Expense Recorded in Consolidated Statement of Operations (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R87.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Additional Information (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R88.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - RSUs and PBRSUs (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R89.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Schedule of Options Activity (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R90.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Black-Scholes Option Pricing Model to Estimate Fair Value of Stock Options Granted (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R91.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Black-Scholes Option Pricing Model to Estimate Fair Value of Stock Options Granted under the ESPP (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R92.htm'},
#  {'short_name': 'Employee Incentive and Retirement Plans - Restructuring (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R93.htm'},
#  {'short_name': 'Income Taxes - Components of tax (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R94.htm'},
#  {'short_name': 'Income Taxes - Additional Information (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R95.htm'},
#  {'short_name': 'Income Taxes - Reconciliation of Income Tax Rate (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R96.htm'},
#  {'short_name': 'Income Taxes - Deferred Tax Assets and Liabilities (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R97.htm'},
#  {'short_name': 'Income Taxes - Unrecognized Tax Benefit (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R98.htm'},
#  {'short_name': 'Commitments and Contingencies - Additional Information (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R99.htm'},
#  {'short_name': 'Commitments and Contingencies - Future Minimum Lease Payments (Detail)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R100.htm'},
#  {'short_name': 'Segment Reporting - Additional Information (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R101.htm'},
#  {'short_name': 'Related Party Transactions (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R102.htm'},
#  {'short_name': 'Quarterly Results of Operations (Unaudited) (Details)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R103.htm'}]

# %%
# we need the data in balance sheet and income statement
statement_list = ['Consolidated Balance Sheets','Consolidated Statements of Operations']

statement_reports = []

for report_dict in all_reports:
    if report_dict['short_name'] in statement_list:
        statement_reports.append(report_dict)

# %%
statement_reports
# Out:
# [{'short_name': 'Consolidated Balance Sheets',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R2.htm'},
#  {'short_name': 'Consolidated Statements of Operations',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1409970/000140997019000222/R4.htm'}]

# %%
# extract data in balance sheet
# create a dictionary to store the related data 
BS_data = {}
BS_data['headers'] = []
BS_data['data'] = []

# %%
# url for 'Consolidated Balance Sheets'
BS_url = statement_reports[0]['url']

BS_content = requests.get(BS_url).content

BS_soup = BeautifulSoup(BS_content, 'html.parser')

# use for loop to loop through all 'tr'
for index, row in enumerate(BS_soup.table.find_all('tr')):
    
    # in each 'tr', each 'td' represent data in a column
    cols = row.find_all('td')
    
    # if it is not header and not in bold, it is the data row
    # extract data in this row
    if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0):
        reg_row = [ele.text.strip() for ele in cols]
        BS_data['data'].append(reg_row)
    
    # extract the header information
    elif (len(row.find_all('th')) != 0):
        hed_row = [ele.text.strip() for ele in row.find_all('th')]
        BS_data['headers'].append(hed_row)
    
    else:
        pass

# %%
# create a dataframe for storing the data
BS_data_df = pd.DataFrame(BS_data['data'])

# drop the column which is irrelevant
BS_data_df = BS_data_df.drop(1, axis = 1)

# assign the 'headers' into the dataframe
BS_data_df.columns = BS_data['headers'][0]

# rename the column name
BS_data_df.rename({'Consolidated Balance Sheets - USD ($) $ in Thousands': 'Data Name'}, axis=1, inplace=True)

# drop the row which is irrelevant
BS_data_df.drop(BS_data_df.tail(3).index, inplace=True)

# %%
BS_data_df.tail()
# Out:
#                                         Data Name Dec. 31, 2018 Dec. 31, 2017
# 24  Accumulated other comprehensive income (loss)           157           (5)
# 25         Total LendingClub stockholders’ equity       869,201       922,495
# 26                       Noncontrolling interests         1,780         5,262
# 27                                   Total equity       870,981       927,757
# 28                   Total liabilities and equity   $ 3,819,527   $ 4,640,831

# %%
# extract data in income statement
# create a dictionary to store the related data 
IS_data = {}
IS_data['headers'] = []
IS_data['data'] = []

# %%
# url for 'Consolidated Statements of Operations'
IS_url = statement_reports[1]['url']

IS_content = requests.get(IS_url).content

IS_soup = BeautifulSoup(IS_content, 'html.parser')

# use for loop to loop through all 'tr'
for index, row in enumerate(IS_soup.table.find_all('tr')):
    
    # in each 'tr', each 'td' represent data in a column
    cols = row.find_all('td')
    
    # if it is not header and not in bold, it is the data row
    # extract data in this row
    if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0):
        reg_row = [ele.text.strip() for ele in cols]
        IS_data['data'].append(reg_row)
    
    # extract the header information
    elif (len(row.find_all('th')) != 0):
        hed_row = [ele.text.strip() for ele in row.find_all('th')]
        IS_data['headers'].append(hed_row)
        
    else:
        pass

# %%
# create a dataframe for storing the data
IS_data_df = pd.DataFrame(IS_data['data'])

# create the headers list
IS_data_headers = []
IS_data_headers.append('Data Name')
for item in IS_data['headers'][1]:
    IS_data_headers.append(item)

# assign the 'headers' into the dataframe
IS_data_df.columns = IS_data_headers

# drop the row which is irrelevant
IS_data_df.drop(IS_data_df.tail(4).index, inplace=True)

# get data of 'Dec. 31, 2018' and 'Dec. 31, 2017' under '12 Months Ended'
IS_data_df2 = IS_data_df.iloc[:,[0,9,10]]

# %%
IS_data_df2.tail()
# Out:
#                                             Data Name    Dec. 31, 2018  \
# 19                               LendingClub net loss  $ (128,308,000)
# 20  Basic net loss per share attributable to commo...         $ (0.30)
# 21  Diluted net loss per share attributable to com...         $ (0.30)
# 22    Weighted-average common shares - Basic (shares)      422,917,308
# 23  Weighted-average common shares - Diluted (shares)      422,917,308
#
#       Dec. 31, 2017
# 19  $ (153,835,000)
# 20         $ (0.38)
# 21         $ (0.38)
# 22      408,995,947
# 23      408,995,947

# %%
# create a dataframe to store all extracted data
all_data_df = pd.DataFrame()

# concatenate two dataframe 'BS_data_df' and 'IS_data_df2'
all_data_df = pd.concat([BS_data_df, IS_data_df2], ignore_index=True)

# formatting the number in all_data_df
all_data_df2 = all_data_df.iloc[:,1:3].replace({'[\$, )]':'', '[(]':'-', '': 'NaN'}, regex = True)

all_data_df3 = pd.concat([all_data_df.iloc[:,0], all_data_df2], axis = 1)

# write dataframe to csv
all_data_df3.to_csv('data.csv', index=False)

# %% [markdown]
# ### Part 2: Calculation

# %%
df = pd.read_csv('data.csv', index_col = 0)

# %%
df.head()
# Out:
#                                                     Dec. 31, 2018  \
# Data Name
# Cash and cash equivalents                                372974.0
# Restricted cash (1)                                      271084.0
# Securities available for sale (includes $53,611...       170469.0
# Loans held for investment at fair value (1)             1883251.0
# Loans held for investment by the Company at fai...         2583.0
#
#                                                     Dec. 31, 2017
# Data Name
# Cash and cash equivalents                                401719.0
# Restricted cash (1)                                      242570.0
# Securities available for sale (includes $53,611...       117573.0
# Loans held for investment at fair value (1)             2932325.0
# Loans held for investment by the Company at fai...       361230.0

# %%
# change df to dictionary as df_dict
df_dict = df.to_dict()

# %%
# create a dictionary to store data for calculating the ratio
ratio_data_dict = {}

# for 'Current Assets'
ratio_data_dict['Current Assets'] = df_dict['Dec. 31, 2018']['Cash and cash equivalents'] + df_dict['Dec. 31, 2018']['Restricted cash (1)'] + df_dict['Dec. 31, 2018']['Securities available for sale (includes $53,611 and $0 pledged as collateral at fair value, respectively)'] + df_dict['Dec. 31, 2018']['Loans held for investment at fair value (1)'] + df_dict['Dec. 31, 2018']['Loans held for investment by the Company at fair value (1)'] + df_dict['Dec. 31, 2018']['Loans held for sale by the Company at fair value (1)'] + df_dict['Dec. 31, 2018']['Accrued interest receivable (1)'] 

# for 'Quick Assets'
ratio_data_dict['Quick Assets'] = df_dict['Dec. 31, 2018']['Cash and cash equivalents'] + df_dict['Dec. 31, 2018']['Restricted cash (1)'] + df_dict['Dec. 31, 2018']['Securities available for sale (includes $53,611 and $0 pledged as collateral at fair value, respectively)'] + df_dict['Dec. 31, 2018']['Loans held for investment at fair value (1)'] + df_dict['Dec. 31, 2018']['Loans held for investment by the Company at fair value (1)'] + df_dict['Dec. 31, 2018']['Loans held for sale by the Company at fair value (1)'] + df_dict['Dec. 31, 2018']['Accrued interest receivable (1)'] 

# for 'Cash + Marketable Securities'
ratio_data_dict['Cash + Marketable Securities'] = df_dict['Dec. 31, 2018']['Cash and cash equivalents'] + df_dict['Dec. 31, 2018']['Restricted cash (1)'] + df_dict['Dec. 31, 2018']['Securities available for sale (includes $53,611 and $0 pledged as collateral at fair value, respectively)']                    

# for 'Average Inventory'
# there is no related data for 'Inventory', so 'None' is assigned here
ratio_data_dict['Average Inventory'] = None

# for 'Total Asset'
ratio_data_dict['Total Asset'] = df_dict['Dec. 31, 2018']['Total assets']        

# for 'Current Liabilities'
ratio_data_dict['Current Liabilities'] = df_dict['Dec. 31, 2018']['Accounts payable'] + df_dict['Dec. 31, 2018']['Accrued interest payable (1)'] + df_dict['Dec. 31, 2018']['Accrued expenses and other liabilities (1)']                    

# for 'Total Debt'
ratio_data_dict['Total Debt'] = df_dict['Dec. 31, 2018']['Payable to investors'] + df_dict['Dec. 31, 2018']['Notes, certificates and secured borrowings at fair value (1)'] + df_dict['Dec. 31, 2018']['Payable to securitization note and residual certificate holders (includes $0 and$1,479 at fair value, respectively) (1)'] + df_dict['Dec. 31, 2018']['Credit facilities and securities sold under repurchase agreements (1)']                     

# for 'Total Liabilities'
ratio_data_dict['Total Liabilities'] = df_dict['Dec. 31, 2018']['Total liabilities']

# for 'Total Equity'
ratio_data_dict['Total Equity'] = df_dict['Dec. 31, 2018']['Total equity']

# for 'Revenue'
ratio_data_dict['Revenue'] = df_dict['Dec. 31, 2018']['Net revenue, fees'] 

# for 'Cost of Goods Sold'
ratio_data_dict['Cost of Goods Sold'] = df_dict['Dec. 31, 2018']['Gain (Loss) on sales of loans']

# for 'Net Revenue'
ratio_data_dict['Net Revenue'] = df_dict['Dec. 31, 2018']['Total net revenue']

# for 'Operating Expenses'
ratio_data_dict['Operating Expenses'] = df_dict['Dec. 31, 2018']['Total operating expenses']

# for 'Non Operating Income'
# there is no related data for 'Non Operating Income', so 'None' is assigned here
ratio_data_dict['Non Operating Income'] = None

# for 'Earnings Before Interest and Taxes'
ratio_data_dict['Earnings Before Interest and Taxes'] = df_dict['Dec. 31, 2018']['Loss before income tax expense']

# for 'Interest Expense'
ratio_data_dict['Interest Expense'] = df_dict['Dec. 31, 2018']['Interest expense']

# for 'Net Income'
ratio_data_dict['Net Income'] = df_dict['Dec. 31, 2018']['LendingClub net loss']

# for 'Preferred Dividend'
# there is no related data for 'Preferred Dividend', so 'None' is assigned here
ratio_data_dict['Preferred Dividend'] = None

# for 'Weighted Average Outstanding Shares'
ratio_data_dict['Weighted Average Outstanding Shares'] = df_dict['Dec. 31, 2018']['Weighted-average common shares - Basic (shares)']

# %%
ratio_data_dict
# Out:
# {'Current Assets': 3562637.0,
#  'Quick Assets': 3562637.0,
#  'Cash + Marketable Securities': 814527.0,
#  'Average Inventory': None,
#  'Total Asset': 3819527.0,
#  'Current Liabilities': 178463.0,
#  'Total Debt': 2770083.0,
#  'Total Liabilities': 2948546.0,
#  'Total Equity': 870981.0,
#  'Revenue': 530587000.0,
#  'Cost of Goods Sold': 45979000.0,
#  'Net Revenue': 694812000.0,
#  'Operating Expenses': 822922000.0,
#  'Non Operating Income': None,
#  'Earnings Before Interest and Taxes': -128110000.0,
#  'Interest Expense': -385605000.0,
#  'Net Income': -128308000.0,
#  'Preferred Dividend': None,
#  'Weighted Average Outstanding Shares': 422917308.0}

# %%
# create a dictionary to store the result for ratio
ratio_result_dict = {}

# Calculate liquidity ratio
ratio_result_dict['Current Ratio'] = ratio_data_dict['Current Assets'] / ratio_data_dict['Current Liabilities'] 
ratio_result_dict['Quick Ratio'] = ratio_data_dict['Quick Assets'] / ratio_data_dict['Current Liabilities']
ratio_result_dict['Cash Ratio'] = ratio_data_dict['Cash + Marketable Securities'] / ratio_data_dict['Current Liabilities']

# calculate profitability ratio
ratio_result_dict['Gross Profit Margin'] = (ratio_data_dict['Revenue'] - ratio_data_dict['Cost of Goods Sold']) / ratio_data_dict['Revenue']
ratio_result_dict['Operating Margin'] = (ratio_data_dict['Revenue'] - ratio_data_dict['Cost of Goods Sold'] - ratio_data_dict['Operating Expenses']) / ratio_data_dict['Revenue']
ratio_result_dict['Profit Margin'] = ratio_data_dict['Net Income'] / ratio_data_dict['Revenue']
ratio_result_dict['Earnings per Share'] = ratio_data_dict['Net Income'] / ratio_data_dict['Weighted Average Outstanding Shares']

# calculate leverage ratio
ratio_result_dict['Debt to Equity Ratio'] = ratio_data_dict['Total Debt'] / ratio_data_dict['Total Equity']
ratio_result_dict['Debt to Asset Ratio'] = ratio_data_dict['Total Debt'] / ratio_data_dict['Total Asset']
ratio_result_dict['Debt Ratio'] = ratio_data_dict['Total Liabilities'] / ratio_data_dict['Total Asset']
ratio_result_dict['Interest Coverage Ratio'] = ratio_data_dict['Earnings Before Interest and Taxes'] / ratio_data_dict['Interest Expense']

# calculate activity ratio / efficiency ratio
ratio_result_dict['Receivable Ratio'] = 'Not Required'
ratio_result_dict['Inventory Turnover Ratio'] = 'Not Applicable'
ratio_result_dict['Asset Turnover Ratio'] = ratio_data_dict['Net Revenue'] / ratio_data_dict['Total Asset']

# %%
# create the list for the index base on four ratio category
index_col = []

ratio_cat = ['Liquidity Ratio', 'Profitability Ratio', 'Leverage Ratio', 'Activity Ratio / Efficiency Ratio']

for item in ratio_cat:
    if (item == 'Liquidity Ratio' or item == 'Activity Ratio / Efficiency Ratio'):
        # repeat the item 3 times
        index_col.extend([item for i in range(3)])
    
    else:
        # repeat the item 4 times
        index_col.extend([item for i in range(4)])

# change the list to dataframe
index_col_df = pd.DataFrame(index_col, columns = ['Category'])

# %%
# change the dictionary to dataframe
# the ratio result can then present in a dataframe
result_df = pd.DataFrame.from_dict(ratio_result_dict, orient='index', columns = ['Result'])

result_df = result_df.reset_index()

result_df.rename(columns = {'index':'Ratio Name'}, inplace = True)

# concatenate two dataframe
result_df = pd.concat([result_df, index_col_df], axis = 1)

# set index in multi-index 
# create the final result dataframe
final_result_df = result_df.set_index(['Category', 'Ratio Name'])

# %%
final_result_df
# Out:
#                                                                     Result
# Category                          Ratio Name
# Liquidity Ratio                   Current Ratio                    19.9629
#                                   Quick Ratio                      19.9629
#                                   Cash Ratio                       4.56412
# Profitability Ratio               Gross Profit Margin             0.913343
#                                   Operating Margin               -0.637622
#                                   Profit Margin                  -0.241823
#                                   Earnings per Share             -0.303388
# Leverage Ratio                    Debt to Equity Ratio             3.18042
#                                   Debt to Asset Ratio             0.725242
#                                   Debt Ratio                      0.771966
#                                   Interest Coverage Ratio         0.332231
# Activity Ratio / Efficiency Ratio Receivable Ratio            Not Required
#                                   Inventory Turnover Ratio  Not Applicable
#                                   Asset Turnover Ratio              181.91
